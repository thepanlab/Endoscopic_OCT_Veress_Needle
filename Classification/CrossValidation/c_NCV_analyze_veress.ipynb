# %% [markdown]
# # Veress Needle Classification
# ## Analyze nested cross-validation
# Justin Reynolds

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
path2data='/Users/justinreynolds/Desktop/21summer/veress/classification/data/c_model_results/v20210817/'
vid_list=[1,2,3,4,5,6,7,8]
arch_dict={0: 'ResNet50', 1: 'InceptionV3', 2: 'Xception'}

# %%
all_loss_dict={}
all_acc_dict={}
avg_loss_dict={}
avg_acc_dict={}

for testvid in vid_list:
    thispath=path2data+'CV'+str(testvid)+'/'
    print("------------------ S%d ------------------"%testvid)
    archie_avg_loss_dict, archie_avg_acc_dict, archie_loss_dict, archie_acc_dict={}, {}, {}, {}
    for arch in arch_dict:
        cv_loss, cv_acc=[], []
        for valvid in vid_list:
            if valvid == testvid:
                continue
            with open(thispath+'cv_y_eval_S%d_V%d_%s.npy'%(testvid, valvid, arch_dict[arch]), 'rb') as f:
                y_eval=np.load(f)
            cv_loss.append(y_eval[0])
            cv_acc.append(y_eval[1])
            print('S%d V%d %s, val_loss: %f, val_acc: %f'%(testvid, valvid, arch_dict[arch], y_eval[0], y_eval[1]))
        
        archie_loss_dict[arch_dict[arch]]=cv_loss
        archie_acc_dict[arch_dict[arch]]=cv_acc
        archie_avg_loss_dict[arch_dict[arch]]=(np.mean(cv_loss), stats.sem(cv_loss))
        archie_avg_acc_dict[arch_dict[arch]]=(np.mean(cv_acc), stats.sem(cv_acc))
        #print("**** S%d %s avg_val_loss: %.3f, avg_val_acc: %.3f *****\n"%(testvid, arch_dict[arch], archie_avg_acc_dict[arch_dict[arch]][0], np.mean(cv_acc)))
    all_loss_dict[testvid]=archie_loss_dict
    all_acc_dict[testvid]=archie_acc_dict
    avg_loss_dict[testvid]=archie_avg_loss_dict
    avg_acc_dict[testvid]=archie_avg_acc_dict
    print('\n***** S%d Cross-Validation Average Accuracies (per model) *****'%testvid)
    print('%s:    %f ± %f'%(arch_dict[0], avg_acc_dict[testvid][arch_dict[0]][0], avg_acc_dict[testvid][arch_dict[0]][1]))
    print('%s: %f ± %f'%(arch_dict[1], avg_acc_dict[testvid][arch_dict[1]][0], avg_acc_dict[testvid][arch_dict[1]][1]))
    print('%s:    %f ± %f'%(arch_dict[2], avg_acc_dict[testvid][arch_dict[2]][0], avg_acc_dict[testvid][arch_dict[2]][1]))
    print("\n")
# Out:
# ------------------ S1 ------------------
# S1 V2 ResNet50, val_loss: 0.282122, val_acc: 0.871500
# S1 V3 ResNet50, val_loss: 0.135107, val_acc: 0.949250
# S1 V4 ResNet50, val_loss: 0.105886, val_acc: 0.953750
# S1 V5 ResNet50, val_loss: 0.257227, val_acc: 0.899750
# S1 V6 ResNet50, val_loss: 0.040967, val_acc: 0.984250
# S1 V7 ResNet50, val_loss: 0.317375, val_acc: 0.843500
# S1 V8 ResNet50, val_loss: 0.052514, val_acc: 0.986000
# S1 V2 InceptionV3, val_loss: 0.094496, val_acc: 0.964250
# S1 V3 InceptionV3, val_loss: 0.128068, val_acc: 0.963750
# S1 V4 InceptionV3, val_loss: 0.027669, val_acc: 0.990000
# S1 V5 InceptionV3, val_loss: 0.078765, val_acc: 0.974750
# S1 V6 InceptionV3, val_loss: 0.019084, val_acc: 0.991000
# S1 V7 InceptionV3, val_loss: 0.003212, val_acc: 0.998750
# S1 V8 InceptionV3, val_loss: 0.002111, val_acc: 0.999500
# S1 V2 Xception, val_loss: 0.018352, val_acc: 0.995250
# S1 V3 Xception, val_loss: 0.095402, val_acc: 0.968250
# S1 V4 Xception, val_loss: 0.044307, val_acc: 0.986500
# S1 V5 Xception, val_loss: 0.019583, val_acc: 0.991500
# S1 V6 Xception, val_loss: 0.006610, val_acc: 0.996750
# S1 V7 Xception, val_loss: 0.000614, val_acc: 1.000000
# S1 V8 Xception, val_loss: 0.033176, val_acc: 0.987000
#
# ***** S1 Cross-Validation Average Accuracies (per model) *****
# ResNet50:    0.926857 ± 0.021137
# InceptionV3: 0.983143 ± 0.005821
# Xception:    0.989321 ± 0.003983
#
#
# ------------------ S2 ------------------
# S2 V1 ResNet50, val_loss: 0.170484, val_acc: 0.929000
# S2 V3 ResNet50, val_loss: 0.165943, val_acc: 0.956000
# S2 V4 ResNet50, val_loss: 0.038333, val_acc: 0.990000
# S2 V5 ResNet50, val_loss: 0.104070, val_acc: 0.967000
# S2 V6 ResNet50, val_loss: 0.041779, val_acc: 0.985500
# S2 V7 ResNet50, val_loss: 0.010456, val_acc: 0.997750
# S2 V8 ResNet50, val_loss: 0.024707, val_acc: 0.993250
# S2 V1 InceptionV3, val_loss: 0.061586, val_acc: 0.982000
# S2 V3 InceptionV3, val_loss: 0.097614, val_acc: 0.971250
# S2 V4 InceptionV3, val_loss: 0.037123, val_acc: 0.988500
# S2 V5 InceptionV3, val_loss: 0.089893, val_acc: 0.966750
# S2 V6 InceptionV3, val_loss: 0.036832, val_acc: 0.984750
# S2 V7 InceptionV3, val_loss: 0.006834, val_acc: 0.998500
# S2 V8 InceptionV3, val_loss: 0.001387, val_acc: 0.999500
# S2 V1 Xception, val_loss: 0.074803, val_acc: 0.984250
# S2 V3 Xception, val_loss: 0.074868, val_acc: 0.968000
# S2 V4 Xception, val_loss: 0.033617, val_acc: 0.991000
# S2 V5 Xception, val_loss: 0.022218, val_acc: 0.991250
# S2 V6 Xception, val_loss: 0.034147, val_acc: 0.992750
# S2 V7 Xception, val_loss: 0.016496, val_acc: 0.994500
# S2 V8 Xception, val_loss: 0.002766, val_acc: 0.998750
#
# ***** S2 Cross-Validation Average Accuracies (per model) *****
# ResNet50:    0.974071 ± 0.009412
# InceptionV3: 0.984464 ± 0.004716
# Xception:    0.988643 ± 0.003814
#
#
# ------------------ S3 ------------------
# S3 V1 ResNet50, val_loss: 0.125066, val_acc: 0.957750
# S3 V2 ResNet50, val_loss: 0.161692, val_acc: 0.937250
# S3 V4 ResNet50, val_loss: 0.061943, val_acc: 0.975000
# S3 V5 ResNet50, val_loss: 0.328737, val_acc: 0.853500
# S3 V6 ResNet50, val_loss: 0.027683, val_acc: 0.988250
# S3 V7 ResNet50, val_loss: 0.089143, val_acc: 0.964250
# S3 V8 ResNet50, val_loss: 0.134259, val_acc: 0.948250
# S3 V1 InceptionV3, val_loss: 0.084230, val_acc: 0.966000
# S3 V2 InceptionV3, val_loss: 0.112059, val_acc: 0.967500
# S3 V4 InceptionV3, val_loss: 0.030718, val_acc: 0.988750
# S3 V5 InceptionV3, val_loss: 0.099115, val_acc: 0.962750
# S3 V6 InceptionV3, val_loss: 0.018442, val_acc: 0.993500
# S3 V7 InceptionV3, val_loss: 0.028259, val_acc: 0.992000
# S3 V8 InceptionV3, val_loss: 0.001347, val_acc: 0.999750
# S3 V1 Xception, val_loss: 0.071154, val_acc: 0.976500
# S3 V2 Xception, val_loss: 0.113657, val_acc: 0.948250
# S3 V4 Xception, val_loss: 0.008081, val_acc: 0.996750
# S3 V5 Xception, val_loss: 0.084759, val_acc: 0.974000
# S3 V6 Xception, val_loss: 0.007698, val_acc: 0.996500
# S3 V7 Xception, val_loss: 0.003918, val_acc: 0.998750
# S3 V8 Xception, val_loss: 0.000753, val_acc: 0.999750
#
# ***** S3 Cross-Validation Average Accuracies (per model) *****
# ResNet50:    0.946321 ± 0.016715
# InceptionV3: 0.981464 ± 0.005830
# Xception:    0.984357 ± 0.007267
#
#
# ------------------ S4 ------------------
# S4 V1 ResNet50, val_loss: 0.082175, val_acc: 0.967000
# S4 V2 ResNet50, val_loss: 0.107917, val_acc: 0.952500
# S4 V3 ResNet50, val_loss: 0.150832, val_acc: 0.951250
# S4 V5 ResNet50, val_loss: 0.084215, val_acc: 0.966250
# S4 V6 ResNet50, val_loss: 0.060940, val_acc: 0.975750
# S4 V7 ResNet50, val_loss: 0.061007, val_acc: 0.985000
# S4 V8 ResNet50, val_loss: 0.035913, val_acc: 0.987250
# S4 V1 InceptionV3, val_loss: 0.079735, val_acc: 0.969500
# S4 V2 InceptionV3, val_loss: 0.046404, val_acc: 0.979750
# S4 V3 InceptionV3, val_loss: 0.037950, val_acc: 0.984000
# S4 V5 InceptionV3, val_loss: 0.064885, val_acc: 0.979500
# S4 V6 InceptionV3, val_loss: 0.014546, val_acc: 0.994500
# S4 V7 InceptionV3, val_loss: 0.014222, val_acc: 0.995500
# S4 V8 InceptionV3, val_loss: 0.013738, val_acc: 0.995250
# S4 V1 Xception, val_loss: 0.126327, val_acc: 0.976000
# S4 V2 Xception, val_loss: 0.061607, val_acc: 0.975000
# S4 V3 Xception, val_loss: 0.048024, val_acc: 0.981000
# S4 V5 Xception, val_loss: 0.059001, val_acc: 0.975000
# S4 V6 Xception, val_loss: 0.017204, val_acc: 0.993500
# S4 V7 Xception, val_loss: 0.001772, val_acc: 1.000000
# S4 V8 Xception, val_loss: 0.015838, val_acc: 0.994000
#
# ***** S4 Cross-Validation Average Accuracies (per model) *****
# ResNet50:    0.969286 ± 0.005418
# InceptionV3: 0.985429 ± 0.003790
# Xception:    0.984929 ± 0.004010
#
#
# ------------------ S5 ------------------
# S5 V1 ResNet50, val_loss: 0.219915, val_acc: 0.897000
# S5 V2 ResNet50, val_loss: 0.242160, val_acc: 0.913750
# S5 V3 ResNet50, val_loss: 0.148228, val_acc: 0.942000
# S5 V4 ResNet50, val_loss: 0.107657, val_acc: 0.961500
# S5 V6 ResNet50, val_loss: 0.061124, val_acc: 0.980250
# S5 V7 ResNet50, val_loss: 0.259392, val_acc: 0.894250
# S5 V8 ResNet50, val_loss: 0.413916, val_acc: 0.846750
# S5 V1 InceptionV3, val_loss: 0.074124, val_acc: 0.973250
# S5 V2 InceptionV3, val_loss: 0.159185, val_acc: 0.949000
# S5 V3 InceptionV3, val_loss: 0.059117, val_acc: 0.974750
# S5 V4 InceptionV3, val_loss: 0.081622, val_acc: 0.974250
# S5 V6 InceptionV3, val_loss: 0.024112, val_acc: 0.993500
# S5 V7 InceptionV3, val_loss: 0.021565, val_acc: 0.993250
# S5 V8 InceptionV3, val_loss: 0.020085, val_acc: 0.990750
# S5 V1 Xception, val_loss: 0.045101, val_acc: 0.982500
# S5 V2 Xception, val_loss: 0.042495, val_acc: 0.985250
# S5 V3 Xception, val_loss: 0.069012, val_acc: 0.977250
# S5 V4 Xception, val_loss: 0.019765, val_acc: 0.992000
# S5 V6 Xception, val_loss: 0.004807, val_acc: 0.998500
# S5 V7 Xception, val_loss: 0.006780, val_acc: 0.996500
# S5 V8 Xception, val_loss: 0.001941, val_acc: 0.999500
#
# ***** S5 Cross-Validation Average Accuracies (per model) *****
# ResNet50:    0.919357 ± 0.017203
# InceptionV3: 0.978393 ± 0.006021
# Xception:    0.990214 ± 0.003273
#
#
# ------------------ S6 ------------------
# S6 V1 ResNet50, val_loss: 0.075976, val_acc: 0.978500
# S6 V2 ResNet50, val_loss: 0.147483, val_acc: 0.952000
# S6 V3 ResNet50, val_loss: 0.204092, val_acc: 0.908500
# S6 V4 ResNet50, val_loss: 0.127871, val_acc: 0.951500
# S6 V5 ResNet50, val_loss: 0.097075, val_acc: 0.959500
# S6 V7 ResNet50, val_loss: 0.067671, val_acc: 0.979250
# S6 V8 ResNet50, val_loss: 0.077633, val_acc: 0.982000
# S6 V1 InceptionV3, val_loss: 0.149215, val_acc: 0.957500
# S6 V2 InceptionV3, val_loss: 0.186764, val_acc: 0.909250
# S6 V3 InceptionV3, val_loss: 0.060143, val_acc: 0.976500
# S6 V4 InceptionV3, val_loss: 0.069228, val_acc: 0.976750
# S6 V5 InceptionV3, val_loss: 0.056724, val_acc: 0.980250
# S6 V7 InceptionV3, val_loss: 0.013494, val_acc: 0.996500
# S6 V8 InceptionV3, val_loss: 0.004516, val_acc: 0.998250
# S6 V1 Xception, val_loss: 0.064934, val_acc: 0.985750
# S6 V2 Xception, val_loss: 0.033315, val_acc: 0.987500
# S6 V3 Xception, val_loss: 0.086265, val_acc: 0.968000
# S6 V4 Xception, val_loss: 0.020443, val_acc: 0.990750
# S6 V5 Xception, val_loss: 0.069305, val_acc: 0.967000
# S6 V7 Xception, val_loss: 0.002757, val_acc: 1.000000
# S6 V8 Xception, val_loss: 0.000880, val_acc: 1.000000
#
# ***** S6 Cross-Validation Average Accuracies (per model) *****
# ResNet50:    0.958750 ± 0.009728
# InceptionV3: 0.970714 ± 0.011481
# Xception:    0.985571 ± 0.005119
#
#
# ------------------ S7 ------------------
# S7 V1 ResNet50, val_loss: 0.417771, val_acc: 0.816250
# S7 V2 ResNet50, val_loss: 0.247671, val_acc: 0.892000
# S7 V3 ResNet50, val_loss: 0.171537, val_acc: 0.915250
# S7 V4 ResNet50, val_loss: 0.138700, val_acc: 0.970500
# S7 V5 ResNet50, val_loss: 0.352580, val_acc: 0.821250
# S7 V6 ResNet50, val_loss: 0.032296, val_acc: 0.989000
# S7 V8 ResNet50, val_loss: 0.113547, val_acc: 0.948000
# S7 V1 InceptionV3, val_loss: 0.066043, val_acc: 0.979750
# S7 V2 InceptionV3, val_loss: 0.141391, val_acc: 0.951250
# S7 V3 InceptionV3, val_loss: 0.085236, val_acc: 0.976000
# S7 V4 InceptionV3, val_loss: 0.025721, val_acc: 0.989500
# S7 V5 InceptionV3, val_loss: 0.049281, val_acc: 0.978750
# S7 V6 InceptionV3, val_loss: 0.011705, val_acc: 0.995000
# S7 V8 InceptionV3, val_loss: 0.021775, val_acc: 0.990500
# S7 V1 Xception, val_loss: 0.070929, val_acc: 0.973500
# S7 V2 Xception, val_loss: 0.074140, val_acc: 0.972750
# S7 V3 Xception, val_loss: 0.056716, val_acc: 0.973250
# S7 V4 Xception, val_loss: 0.007900, val_acc: 0.997500
# S7 V5 Xception, val_loss: 0.017242, val_acc: 0.991750
# S7 V6 Xception, val_loss: 0.013276, val_acc: 0.994750
# S7 V8 Xception, val_loss: 0.003334, val_acc: 0.998750
#
# ***** S7 Cross-Validation Average Accuracies (per model) *****
# ResNet50:    0.907464 ± 0.025966
# InceptionV3: 0.980107 ± 0.005498
# Xception:    0.986036 ± 0.004626
#
#
# ------------------ S8 ------------------
# S8 V1 ResNet50, val_loss: 0.063649, val_acc: 0.976000
# S8 V2 ResNet50, val_loss: 0.257111, val_acc: 0.903000
# S8 V3 ResNet50, val_loss: 0.084719, val_acc: 0.967750
# S8 V4 ResNet50, val_loss: 0.054847, val_acc: 0.980750
# S8 V5 ResNet50, val_loss: 0.065286, val_acc: 0.976750
# S8 V6 ResNet50, val_loss: 0.019721, val_acc: 0.994500
# S8 V7 ResNet50, val_loss: 0.046067, val_acc: 0.984000
# S8 V1 InceptionV3, val_loss: 0.063750, val_acc: 0.982500
# S8 V2 InceptionV3, val_loss: 0.101749, val_acc: 0.963750
# S8 V3 InceptionV3, val_loss: 0.058453, val_acc: 0.980750
# S8 V4 InceptionV3, val_loss: 0.059608, val_acc: 0.976250
# S8 V5 InceptionV3, val_loss: 0.180065, val_acc: 0.958750
# S8 V6 InceptionV3, val_loss: 0.009712, val_acc: 0.996750
# S8 V7 InceptionV3, val_loss: 0.009148, val_acc: 0.997500
# S8 V1 Xception, val_loss: 0.086529, val_acc: 0.979500
# S8 V2 Xception, val_loss: 0.081099, val_acc: 0.970500
# S8 V3 Xception, val_loss: 0.071015, val_acc: 0.977500
# S8 V4 Xception, val_loss: 0.017089, val_acc: 0.990250
# S8 V5 Xception, val_loss: 0.018280, val_acc: 0.992500
# S8 V6 Xception, val_loss: 0.037744, val_acc: 0.988500
# S8 V7 Xception, val_loss: 0.001622, val_acc: 0.999500
#
# ***** S8 Cross-Validation Average Accuracies (per model) *****
# ResNet50:    0.968964 ± 0.011423
# InceptionV3: 0.979464 ± 0.005609
# Xception:    0.985464 ± 0.003785

# %%
for testvid in all_acc_dict:
    my_list=[]
    for arch in arch_dict:
        print("S%d avg_acc_%s = %f"%(testvid, arch_dict[arch], np.mean(all_acc_dict[testvid][arch_dict[arch]])))
        my_list.append(np.mean(all_acc_dict[testvid][arch_dict[arch]]))
    print("*** S%d winner: %s == %f ***"%(testvid, arch_dict[np.argmax(my_list)], np.max(my_list), ))
    print("\n")
# Out:
# S1 avg_acc_ResNet50 = 0.926857
# S1 avg_acc_InceptionV3 = 0.983143
# S1 avg_acc_Xception = 0.989321
# *** S1 winner: Xception == 0.989321 ***
#
#
# S2 avg_acc_ResNet50 = 0.974071
# S2 avg_acc_InceptionV3 = 0.984464
# S2 avg_acc_Xception = 0.988643
# *** S2 winner: Xception == 0.988643 ***
#
#
# S3 avg_acc_ResNet50 = 0.946321
# S3 avg_acc_InceptionV3 = 0.981464
# S3 avg_acc_Xception = 0.984357
# *** S3 winner: Xception == 0.984357 ***
#
#
# S4 avg_acc_ResNet50 = 0.969286
# S4 avg_acc_InceptionV3 = 0.985429
# S4 avg_acc_Xception = 0.984929
# *** S4 winner: InceptionV3 == 0.985429 ***
#
#
# S5 avg_acc_ResNet50 = 0.919357
# S5 avg_acc_InceptionV3 = 0.978393
# S5 avg_acc_Xception = 0.990214
# *** S5 winner: Xception == 0.990214 ***
#
#
# S6 avg_acc_ResNet50 = 0.958750
# S6 avg_acc_InceptionV3 = 0.970714
# S6 avg_acc_Xception = 0.985571
# *** S6 winner: Xception == 0.985571 ***
#
#
# S7 avg_acc_ResNet50 = 0.907464
# S7 avg_acc_InceptionV3 = 0.980107
# S7 avg_acc_Xception = 0.986036
# *** S7 winner: Xception == 0.986036 ***
#
#
# S8 avg_acc_ResNet50 = 0.968964
# S8 avg_acc_InceptionV3 = 0.979464
# S8 avg_acc_Xception = 0.985464
# *** S8 winner: Xception == 0.985464 ***
